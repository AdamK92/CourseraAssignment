# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Adam K
# Research and Development Manager

# %% [markdown]
# *I am interested in data science because I think technology is the future. I see Data Science, for me, as a next step in my career: something I can do to build on my previous knowledge and experience, while also challenging me to grow and learn new things.*

# %% [markdown]
# ### The following code checks to see if the x value is greater than the y value. If so, then it prints "x is greater than y". If not, then it prints "x is less than or equal to y".

# %%
x=y
y=1

if x > y:
    print (x, "is greater than", y)
else:
    print (x, "is less than or equal to", y)
# Out:
# 1 is less than or equal to 1

# %% [markdown]
# This is a set a of sample text, including:
# - bullet points
# - ~~strikethrough~~
# - <font color=blue>coloured text</font>
# - horizontal line (below)
# - and an image (below)
# ***
# ![s960_thank_you_sticky_note.jpg](attachment:3e8e1e8e-c773-4595-8d36-504048366f04.jpg)
